# %% [markdown]
# <a href="https://colab.research.google.com/github/PrncssAnnMrgrtUy/ITBA3204_FightTheBite/blob/main/FightTheBite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime

# %%
url='https://raw.githubusercontent.com/PrncssAnnMrgrtUy/ITBA3204_FightTheBite/main/Datasets/ph_dengue_cases2016-2020.csv'
df = pd.read_csv(url)
df.head().style.background_gradient(cmap='flare')
# Out:
# <style type="text/css">
# #T_d171a_row0_col1, #T_d171a_row1_col1, #T_d171a_row1_col4, #T_d171a_row2_col1, #T_d171a_row2_col4, #T_d171a_row3_col1, #T_d171a_row3_col3, #T_d171a_row4_col1 {
#   background-color: #edb081;
#   color: #000000;
# }
# #T_d171a_row0_col3, #T_d171a_row3_col4 {
#   background-color: #4b2362;
#   color: #f1f1f1;
# }
# #T_d171a_row0_col4, #T_d171a_row4_col4 {
#   background-color: #c14168;
#   color: #f1f1f1;
# }
# #T_d171a_row1_col3 {
#   background-color: #e3685c;
#   color: #f1f1f1;
# }
# #T_d171a_row2_col3 {
#   background-color: #eb9d75;
#   color: #000000;
# }
# #T_d171a_row4_col3 {
#   background-color: #edaf80;
#   color: #000000;
# }
# </style>
# <table id="T_d171a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d171a_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_d171a_level0_col1" class="col_heading level0 col1" >Year</th>
#       <th id="T_d171a_level0_col2" class="col_heading level0 col2" >Region</th>
#       <th id="T_d171a_level0_col3" class="col_heading level0 col3" >Dengue_Cases</th>
#       <th id="T_d171a_level0_col4" class="col_heading level0 col4" >Dengue_Deaths</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d171a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d171a_row0_col0" class="data row0 col0" >January</td>
#       <td id="T_d171a_row0_col1" class="data row0 col1" >2016</td>
#       <td id="T_d171a_row0_col2" class="data row0 col2" >Region I</td>
#       <td id="T_d171a_row0_col3" class="data row0 col3" >705</td>
#       <td id="T_d171a_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d171a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d171a_row1_col0" class="data row1 col0" >February</td>
#       <td id="T_d171a_row1_col1" class="data row1 col1" >2016</td>
#       <td id="T_d171a_row1_col2" class="data row1 col2" >Region I</td>
#       <td id="T_d171a_row1_col3" class="data row1 col3" >374</td>
#       <td id="T_d171a_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d171a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d171a_row2_col0" class="data row2 col0" >March</td>
#       <td id="T_d171a_row2_col1" class="data row2 col1" >2016</td>
#       <td id="T_d171a_row2_col2" class="data row2 col2" >Region I</td>
#       <td id="T_d171a_row2_col3" class="data row2 col3" >276</td>
#       <td id="T_d171a_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d171a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d171a_row3_col0" class="data row3 col0" >April</td>
#       <td id="T_d171a_row3_col1" class="data row3 col1" >2016</td>
#       <td id="T_d171a_row3_col2" class="data row3 col2" >Region I</td>
#       <td id="T_d171a_row3_col3" class="data row3 col3" >240</td>
#       <td id="T_d171a_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d171a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d171a_row4_col0" class="data row4 col0" >May</td>
#       <td id="T_d171a_row4_col1" class="data row4 col1" >2016</td>
#       <td id="T_d171a_row4_col2" class="data row4 col2" >Region I</td>
#       <td id="T_d171a_row4_col3" class="data row4 col3" >243</td>
#       <td id="T_d171a_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.tail().style.background_gradient(cmap='flare')
# Out:
# <style type="text/css">
# #T_38c7d_row0_col1, #T_38c7d_row0_col4, #T_38c7d_row1_col1, #T_38c7d_row2_col1, #T_38c7d_row2_col3, #T_38c7d_row3_col1, #T_38c7d_row4_col1, #T_38c7d_row4_col4 {
#   background-color: #edb081;
#   color: #000000;
# }
# #T_38c7d_row0_col3, #T_38c7d_row2_col4 {
#   background-color: #4b2362;
#   color: #f1f1f1;
# }
# #T_38c7d_row1_col3 {
#   background-color: #eca77b;
#   color: #000000;
# }
# #T_38c7d_row1_col4 {
#   background-color: #642a6a;
#   color: #f1f1f1;
# }
# #T_38c7d_row3_col3 {
#   background-color: #ecaa7d;
#   color: #000000;
# }
# #T_38c7d_row3_col4 {
#   background-color: #ea9570;
#   color: #f1f1f1;
# }
# #T_38c7d_row4_col3 {
#   background-color: #ea916e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_38c7d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38c7d_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_38c7d_level0_col1" class="col_heading level0 col1" >Year</th>
#       <th id="T_38c7d_level0_col2" class="col_heading level0 col2" >Region</th>
#       <th id="T_38c7d_level0_col3" class="col_heading level0 col3" >Dengue_Cases</th>
#       <th id="T_38c7d_level0_col4" class="col_heading level0 col4" >Dengue_Deaths</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38c7d_level0_row0" class="row_heading level0 row0" >1015</th>
#       <td id="T_38c7d_row0_col0" class="data row0 col0" >August</td>
#       <td id="T_38c7d_row0_col1" class="data row0 col1" >2020</td>
#       <td id="T_38c7d_row0_col2" class="data row0 col2" >BARMM</td>
#       <td id="T_38c7d_row0_col3" class="data row0 col3" >91</td>
#       <td id="T_38c7d_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_38c7d_level0_row1" class="row_heading level0 row1" >1016</th>
#       <td id="T_38c7d_row1_col0" class="data row1 col0" >September</td>
#       <td id="T_38c7d_row1_col1" class="data row1 col1" >2020</td>
#       <td id="T_38c7d_row1_col2" class="data row1 col2" >BARMM</td>
#       <td id="T_38c7d_row1_col3" class="data row1 col3" >16</td>
#       <td id="T_38c7d_row1_col4" class="data row1 col4" >8</td>
#     </tr>
#     <tr>
#       <th id="T_38c7d_level0_row2" class="row_heading level0 row2" >1017</th>
#       <td id="T_38c7d_row2_col0" class="data row2 col0" >October</td>
#       <td id="T_38c7d_row2_col1" class="data row2 col1" >2020</td>
#       <td id="T_38c7d_row2_col2" class="data row2 col2" >BARMM</td>
#       <td id="T_38c7d_row2_col3" class="data row2 col3" >13</td>
#       <td id="T_38c7d_row2_col4" class="data row2 col4" >9</td>
#     </tr>
#     <tr>
#       <th id="T_38c7d_level0_row3" class="row_heading level0 row3" >1018</th>
#       <td id="T_38c7d_row3_col0" class="data row3 col0" >November</td>
#       <td id="T_38c7d_row3_col1" class="data row3 col1" >2020</td>
#       <td id="T_38c7d_row3_col2" class="data row3 col2" >BARMM</td>
#       <td id="T_38c7d_row3_col3" class="data row3 col3" >15</td>
#       <td id="T_38c7d_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_38c7d_level0_row4" class="row_heading level0 row4" >1019</th>
#       <td id="T_38c7d_row4_col0" class="data row4 col0" >December</td>
#       <td id="T_38c7d_row4_col1" class="data row4 col1" >2020</td>
#       <td id="T_38c7d_row4_col2" class="data row4 col2" >BARMM</td>
#       <td id="T_38c7d_row4_col3" class="data row4 col3" >23</td>
#       <td id="T_38c7d_row4_col4" class="data row4 col4" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (602, 26)

# %%
df.isnull().sum()
# Out:
# Month            0
# Year             0
# Region           0
# Dengue_Cases     0
# Dengue_Deaths    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Month          1020 non-null   object
#  1   Year           1020 non-null   int64
#  2   Region         1020 non-null   object
#  3   Dengue_Cases   1020 non-null   int64
#  4   Dengue_Deaths  1020 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 40.0+ KB

# %%
df.describe().style.background_gradient(cmap='flare')
# Out:
# <style type="text/css">
# #T_1170e_row0_col0 {
#   background-color: #c14068;
#   color: #f1f1f1;
# }
# #T_1170e_row0_col1 {
#   background-color: #eca57a;
#   color: #000000;
# }
# #T_1170e_row0_col2 {
#   background-color: #a5396e;
#   color: #f1f1f1;
# }
# #T_1170e_row1_col0, #T_1170e_row3_col0, #T_1170e_row4_col0, #T_1170e_row5_col0, #T_1170e_row6_col0, #T_1170e_row7_col0, #T_1170e_row7_col1, #T_1170e_row7_col2 {
#   background-color: #4b2362;
#   color: #f1f1f1;
# }
# #T_1170e_row1_col1 {
#   background-color: #eca379;
#   color: #000000;
# }
# #T_1170e_row1_col2, #T_1170e_row4_col1 {
#   background-color: #edae7f;
#   color: #000000;
# }
# #T_1170e_row2_col0, #T_1170e_row3_col1, #T_1170e_row3_col2, #T_1170e_row4_col2, #T_1170e_row5_col2 {
#   background-color: #edb081;
#   color: #000000;
# }
# #T_1170e_row2_col1 {
#   background-color: #eb9d75;
#   color: #000000;
# }
# #T_1170e_row2_col2 {
#   background-color: #eca278;
#   color: #000000;
# }
# #T_1170e_row5_col1 {
#   background-color: #ecaa7d;
#   color: #000000;
# }
# #T_1170e_row6_col1 {
#   background-color: #eca178;
#   color: #000000;
# }
# #T_1170e_row6_col2 {
#   background-color: #edaf80;
#   color: #000000;
# }
# </style>
# <table id="T_1170e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1170e_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_1170e_level0_col1" class="col_heading level0 col1" >Dengue_Cases</th>
#       <th id="T_1170e_level0_col2" class="col_heading level0 col2" >Dengue_Deaths</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1170e_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_1170e_row0_col0" class="data row0 col0" >1020.000000</td>
#       <td id="T_1170e_row0_col1" class="data row0 col1" >1020.000000</td>
#       <td id="T_1170e_row0_col2" class="data row0 col2" >1020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1170e_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_1170e_row1_col0" class="data row1 col0" >2018.000000</td>
#       <td id="T_1170e_row1_col1" class="data row1 col1" >1124.926471</td>
#       <td id="T_1170e_row1_col2" class="data row1 col2" >16.513725</td>
#     </tr>
#     <tr>
#       <th id="T_1170e_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_1170e_row2_col0" class="data row2 col0" >1.414907</td>
#       <td id="T_1170e_row2_col1" class="data row2 col1" >1662.608878</td>
#       <td id="T_1170e_row2_col2" class="data row2 col2" >96.358215</td>
#     </tr>
#     <tr>
#       <th id="T_1170e_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_1170e_row3_col0" class="data row3 col0" >2016.000000</td>
#       <td id="T_1170e_row3_col1" class="data row3 col1" >10.000000</td>
#       <td id="T_1170e_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1170e_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_1170e_row4_col0" class="data row4 col0" >2017.000000</td>
#       <td id="T_1170e_row4_col1" class="data row4 col1" >247.750000</td>
#       <td id="T_1170e_row4_col2" class="data row4 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1170e_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_1170e_row5_col0" class="data row5 col0" >2018.000000</td>
#       <td id="T_1170e_row5_col1" class="data row5 col1" >582.500000</td>
#       <td id="T_1170e_row5_col2" class="data row5 col2" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1170e_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_1170e_row6_col0" class="data row6 col0" >2019.000000</td>
#       <td id="T_1170e_row6_col1" class="data row6 col1" >1284.250000</td>
#       <td id="T_1170e_row6_col2" class="data row6 col2" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1170e_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_1170e_row7_col0" class="data row7 col0" >2020.000000</td>
#       <td id="T_1170e_row7_col1" class="data row7 col1" >21658.000000</td>
#       <td id="T_1170e_row7_col2" class="data row7 col2" >1651.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.unique(df['Region'])
# Out:
# array(['BARMM', 'CAR', 'NCR', 'Region I', 'Region II', 'Region III',
#        'Region IV-A', 'Region IV-B', 'Region IX', 'Region V', 'Region VI',
#        'Region VII', 'Region VIII', 'Region X', 'Region XI', 'Region XII',
#        'Region XIII'], dtype=object)

# %%
index = 0
monthYears = []
years = [i for i in df.Year]
for i in df.Month:
    monthYears.append(str(years[index])+'-'+str(i))
    index += 1
plt.figure(figsize=(14,6))
sns.lineplot(x=monthYears,y=[i for i in df['Dengue_Cases']],color='purple')
plt.title(label='Dengue fever cases from 2016-2020')
plt.xlabel(xlabel='Month')
plt.ylabel(ylabel='Cases')
plt.xticks(rotation=90)
plt.show()

# %%
index = 0
dates = []
for i in df['Month']:
    dates.append(str([j for j in df['Year']][index])+'-'+i)
    index += 1
    
data = {'Date': dates,
        'Region': [i for i in df['Region']],
        'Dengue_Cases': [i for i in df['Dengue_Cases']],
        'Dengue_Deaths': [i for i in df['Dengue_Deaths']]}
cleanDF = pd.DataFrame(data)
cleanDF.head().style.background_gradient(cmap='flare')
# Out:
# <style type="text/css">
# #T_64ce3_row0_col2, #T_64ce3_row3_col3 {
#   background-color: #4b2362;
#   color: #f1f1f1;
# }
# #T_64ce3_row0_col3, #T_64ce3_row4_col3 {
#   background-color: #c14168;
#   color: #f1f1f1;
# }
# #T_64ce3_row1_col2 {
#   background-color: #e3685c;
#   color: #f1f1f1;
# }
# #T_64ce3_row1_col3, #T_64ce3_row2_col3, #T_64ce3_row3_col2 {
#   background-color: #edb081;
#   color: #000000;
# }
# #T_64ce3_row2_col2 {
#   background-color: #eb9d75;
#   color: #000000;
# }
# #T_64ce3_row4_col2 {
#   background-color: #edaf80;
#   color: #000000;
# }
# </style>
# <table id="T_64ce3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64ce3_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_64ce3_level0_col1" class="col_heading level0 col1" >Region</th>
#       <th id="T_64ce3_level0_col2" class="col_heading level0 col2" >Dengue_Cases</th>
#       <th id="T_64ce3_level0_col3" class="col_heading level0 col3" >Dengue_Deaths</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64ce3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64ce3_row0_col0" class="data row0 col0" >2016-January</td>
#       <td id="T_64ce3_row0_col1" class="data row0 col1" >Region I</td>
#       <td id="T_64ce3_row0_col2" class="data row0 col2" >705</td>
#       <td id="T_64ce3_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_64ce3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64ce3_row1_col0" class="data row1 col0" >2016-February</td>
#       <td id="T_64ce3_row1_col1" class="data row1 col1" >Region I</td>
#       <td id="T_64ce3_row1_col2" class="data row1 col2" >374</td>
#       <td id="T_64ce3_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_64ce3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_64ce3_row2_col0" class="data row2 col0" >2016-March</td>
#       <td id="T_64ce3_row2_col1" class="data row2 col1" >Region I</td>
#       <td id="T_64ce3_row2_col2" class="data row2 col2" >276</td>
#       <td id="T_64ce3_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_64ce3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_64ce3_row3_col0" class="data row3 col0" >2016-April</td>
#       <td id="T_64ce3_row3_col1" class="data row3 col1" >Region I</td>
#       <td id="T_64ce3_row3_col2" class="data row3 col2" >240</td>
#       <td id="T_64ce3_row3_col3" class="data row3 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_64ce3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_64ce3_row4_col0" class="data row4 col0" >2016-May</td>
#       <td id="T_64ce3_row4_col1" class="data row4 col1" >Region I</td>
#       <td id="T_64ce3_row4_col2" class="data row4 col2" >243</td>
#       <td id="T_64ce3_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
uniqueDates = []
for i in [j for j in cleanDF['Date']]:
    if i not in uniqueDates:
        uniqueDates.append(i)
totalCases = []
for i in uniqueDates:
    tempDF = cleanDF.query("Date == '{}'".format(i))
    totalCases.append([datetime.datetime.strptime(i.split('-')[1], '%B').month,
                       int(i.split('-')[0]),sum([i for i in tempDF['Dengue_Cases']])])
casesDF = pd.DataFrame(totalCases,columns=['Month','Year','Cases'])
plt.figure(figsize=(14,6))
sns.heatmap(casesDF.pivot("Month", "Year", "Cases"))
plt.title(label='Heatmap of infection cases for months and years in the period of 2016-2022')
plt.show()
# Out:
# <ipython-input-30-e2cbb996a113>:12: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.heatmap(casesDF.pivot("Month", "Year", "Cases"))

# %%
regionCases = []
for i in np.unique(cleanDF['Region']):
    tempDF = cleanDF.query("Region == '{}'".format(i))
    regionCases.append([sum([i for i in tempDF['Dengue_Cases']]),i])
regionCases.sort()

# %%
x = [i[0] for i in regionCases]
y = [i[1] for i in regionCases]

colors = sns.color_palette("flare")
plt.figure(figsize=(14,6))
sns.barplot(x=x,y=y,palette=colors)
plt.title(label='Total cases per region from 2016-2020',pad=35)
plt.xlabel(xlabel='Cases',labelpad=35)
plt.ylabel(ylabel='Region',labelpad=35)
plt.show()

# %%
cleanDF.head().style.background_gradient(cmap='flare')
# Out:
# <style type="text/css">
# #T_7a8ee_row0_col2, #T_7a8ee_row3_col3 {
#   background-color: #4b2362;
#   color: #f1f1f1;
# }
# #T_7a8ee_row0_col3, #T_7a8ee_row4_col3 {
#   background-color: #c14168;
#   color: #f1f1f1;
# }
# #T_7a8ee_row1_col2 {
#   background-color: #e3685c;
#   color: #f1f1f1;
# }
# #T_7a8ee_row1_col3, #T_7a8ee_row2_col3, #T_7a8ee_row3_col2 {
#   background-color: #edb081;
#   color: #000000;
# }
# #T_7a8ee_row2_col2 {
#   background-color: #eb9d75;
#   color: #000000;
# }
# #T_7a8ee_row4_col2 {
#   background-color: #edaf80;
#   color: #000000;
# }
# </style>
# <table id="T_7a8ee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a8ee_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_7a8ee_level0_col1" class="col_heading level0 col1" >Region</th>
#       <th id="T_7a8ee_level0_col2" class="col_heading level0 col2" >Dengue_Cases</th>
#       <th id="T_7a8ee_level0_col3" class="col_heading level0 col3" >Dengue_Deaths</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a8ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a8ee_row0_col0" class="data row0 col0" >2016-January</td>
#       <td id="T_7a8ee_row0_col1" class="data row0 col1" >Region I</td>
#       <td id="T_7a8ee_row0_col2" class="data row0 col2" >705</td>
#       <td id="T_7a8ee_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7a8ee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a8ee_row1_col0" class="data row1 col0" >2016-February</td>
#       <td id="T_7a8ee_row1_col1" class="data row1 col1" >Region I</td>
#       <td id="T_7a8ee_row1_col2" class="data row1 col2" >374</td>
#       <td id="T_7a8ee_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7a8ee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a8ee_row2_col0" class="data row2 col0" >2016-March</td>
#       <td id="T_7a8ee_row2_col1" class="data row2 col1" >Region I</td>
#       <td id="T_7a8ee_row2_col2" class="data row2 col2" >276</td>
#       <td id="T_7a8ee_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7a8ee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a8ee_row3_col0" class="data row3 col0" >2016-April</td>
#       <td id="T_7a8ee_row3_col1" class="data row3 col1" >Region I</td>
#       <td id="T_7a8ee_row3_col2" class="data row3 col2" >240</td>
#       <td id="T_7a8ee_row3_col3" class="data row3 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7a8ee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a8ee_row4_col0" class="data row4 col0" >2016-May</td>
#       <td id="T_7a8ee_row4_col1" class="data row4 col1" >Region I</td>
#       <td id="T_7a8ee_row4_col2" class="data row4 col2" >243</td>
#       <td id="T_7a8ee_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
data = []
index = 0
for i in cleanDF['Date']:
    data.append([i,'Cases',[j for j in cleanDF['Dengue_Cases']][index]])
    data.append([i,'Deaths',[k for k in cleanDF['Dengue_Deaths']][index]])
    index += 1
columns = ['Date','Attribute','Total']
alteredDF = pd.DataFrame(data,columns = columns)
alteredDF.head().style.background_gradient(cmap='flare')
# Out:
# <style type="text/css">
# #T_3d2ec_row0_col2 {
#   background-color: #4b2362;
#   color: #f1f1f1;
# }
# #T_3d2ec_row1_col2, #T_3d2ec_row3_col2 {
#   background-color: #edb081;
#   color: #000000;
# }
# #T_3d2ec_row2_col2 {
#   background-color: #bb3f6a;
#   color: #f1f1f1;
# }
# #T_3d2ec_row4_col2 {
#   background-color: #d7505e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3d2ec" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d2ec_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_3d2ec_level0_col1" class="col_heading level0 col1" >Attribute</th>
#       <th id="T_3d2ec_level0_col2" class="col_heading level0 col2" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d2ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d2ec_row0_col0" class="data row0 col0" >2016-January</td>
#       <td id="T_3d2ec_row0_col1" class="data row0 col1" >Cases</td>
#       <td id="T_3d2ec_row0_col2" class="data row0 col2" >705</td>
#     </tr>
#     <tr>
#       <th id="T_3d2ec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d2ec_row1_col0" class="data row1 col0" >2016-January</td>
#       <td id="T_3d2ec_row1_col1" class="data row1 col1" >Deaths</td>
#       <td id="T_3d2ec_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3d2ec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d2ec_row2_col0" class="data row2 col0" >2016-February</td>
#       <td id="T_3d2ec_row2_col1" class="data row2 col1" >Cases</td>
#       <td id="T_3d2ec_row2_col2" class="data row2 col2" >374</td>
#     </tr>
#     <tr>
#       <th id="T_3d2ec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d2ec_row3_col0" class="data row3 col0" >2016-February</td>
#       <td id="T_3d2ec_row3_col1" class="data row3 col1" >Deaths</td>
#       <td id="T_3d2ec_row3_col2" class="data row3 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3d2ec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d2ec_row4_col0" class="data row4 col0" >2016-March</td>
#       <td id="T_3d2ec_row4_col1" class="data row4 col1" >Cases</td>
#       <td id="T_3d2ec_row4_col2" class="data row4 col2" >276</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(14,6))
sns.lineplot(x='Date',y='Total',data=alteredDF,hue='Attribute',palette='flare')
plt.title(label='Cases of Dengue against deaths in Philippines 2016-2020')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.lineplot(x=cleanDF.Date,y=cleanDF.Dengue_Deaths,color='purple')
plt.title(label='Dengue Deaths 2016-2020')
plt.xticks(rotation=90)
plt.show()

# %%
cases = [i for i in cleanDF.Dengue_Cases]
deaths = [i for i in cleanDF.Dengue_Deaths]
ratios = []
index = 0
for i in cases:
    ratios.append(deaths[index]/i *100)
plt.figure(figsize=(14,6))
sns.lineplot(x=cleanDF.Date,y=ratios,color='purple')
plt.title(label='Dengue deaths to cases 2016-2020')
plt.ylabel(ylabel='Fatality percentage of total cases (%)')
plt.xticks(rotation=90)
plt.show()

# %%
totals = []
for i in np.unique(cleanDF['Region']):
    tempDF = cleanDF.query("Region == '{}'".format(i))
    totals.append([i,sum([i for i in tempDF['Dengue_Deaths']])])
    
plt.figure(figsize=(20,8))
sns.barplot(x=[i[0] for i in totals],y=[i[1] for i in totals],palette='flare')
plt.ylabel(ylabel='Deaths',labelpad=35)
plt.xlabel(xlabel='Region',labelpad=35)
plt.title(label='Total deaths per region')
plt.show()

# %%
cleanDF.corr().style.background_gradient(cmap='flare')
# Out:
# <ipython-input-25-2f42c1e119ce>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cleanDF.corr().style.background_gradient(cmap='flare')
# <style type="text/css">
# #T_b7d5c_row0_col0, #T_b7d5c_row1_col1 {
#   background-color: #4b2362;
#   color: #f1f1f1;
# }
# #T_b7d5c_row0_col1, #T_b7d5c_row1_col0 {
#   background-color: #edb081;
#   color: #000000;
# }
# </style>
# <table id="T_b7d5c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7d5c_level0_col0" class="col_heading level0 col0" >Dengue_Cases</th>
#       <th id="T_b7d5c_level0_col1" class="col_heading level0 col1" >Dengue_Deaths</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7d5c_level0_row0" class="row_heading level0 row0" >Dengue_Cases</th>
#       <td id="T_b7d5c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b7d5c_row0_col1" class="data row0 col1" >0.038322</td>
#     </tr>
#     <tr>
#       <th id="T_b7d5c_level0_row1" class="row_heading level0 row1" >Dengue_Deaths</th>
#       <td id="T_b7d5c_row1_col0" class="data row1 col0" >0.038322</td>
#       <td id="T_b7d5c_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
totals = []
for i in np.unique(cleanDF['Region']):
    tempDF = cleanDF.query("Region == '{}'".format(i))
    totals.append([i,'Cases',sum([i for i in tempDF['Dengue_Cases']])])
    totals.append([i,'Deaths',sum([i for i in tempDF['Dengue_Deaths']])])
totalsDF = pd.DataFrame(totals,columns=['Region','Type','Total'])

plt.figure(figsize=(20,8))
g = sns.barplot(x='Region', y='Total', hue='Type', data=totalsDF,palette='flare')
plt.title(label='Cases against deaths per region (log scale)',fontsize=14)
g.set_yscale("log")
#g.set_yticklabels([0,10,100,1000,10000,100000])
for bar in g.patches:
  g.annotate(format(bar.get_height(), '.1f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=8, xytext=(0, 8),
                   textcoords='offset points')
plt.show()
